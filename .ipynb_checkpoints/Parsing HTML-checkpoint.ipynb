# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\egorf\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\egorf\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
# !pip install html5lib
# !pip install PyQt5
# Out:
# Requirement already satisfied: html5lib in c:\users\egorf\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\egorf\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\egorf\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Collecting PyQt5
#   Downloading PyQt5-5.15.9-cp37-abi3-win_amd64.whl (6.8 MB)
#      ---------------------------------------- 6.8/6.8 MB 4.6 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.1-cp39-cp39-win_amd64.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 4.5 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# ERROR: Could not install packages due to an OSError: [WinError 5] \u041e\u0442\u043a\u0430\u0437\u0430\u043d\u043e \u0432 \u0434\u043e\u0441\u0442\u0443\u043f\u0435: 'C:\\Users\\egorf\\anaconda3\\Lib\\site-packages\\PyQt5\\QtCore.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import json
from bs4 import BeautifulSoup
import urllib.request
import re
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEnginePage
import sys

class Client(QWebEnginePage):
    
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.loadFinished.connect(self.on_page_load)
        self.setUrl(QUrl(url))
        self.app.exec_()
        
    def on_page_load(self):
        self.app.quit()

def dl_vk_data(group_id, parse, offset=0, count=5, use_dryscrape=False):
    with urllib.request.urlopen(f'https://api.vk.com/method/wall.get?access_token=247f3d70247f3d70247f3d70d6276dfd5c2247f247f3d70478c4cc7443965779421d6d7&owner_id={group_id}&v=5.131&offset={offset}&count={count}') as f:
        json_string = f.read().decode('utf-8')
    json_res = json.loads(json_string)['response']
    for item in json_res['items']:
        print("-" * 50)
        text = item['text']
        print(text)
        for attachment in item['attachments']:
            link = attachment.get('link')
            if link:
                url = link['url']
                print(url)
                if use_dryscrape:
                    Client(url).toHtml(lambda arg: print(arg))
                else:
                    with urllib.request.urlopen(url) as f:
                        html = f.read().decode('utf-8')
                    parse(html)

# %%
def parse_rbc(html):
    soup = BeautifulSoup(html)
            
    title_html = soup.find("div", class_="article__header__title")
    if title_html:
        title = str(title_html.h1.string).strip()
        print(title)

    article_html = soup.find("div", class_="article__text")
    if article_html:
        paragraphs = article_html.find_all(re.compile("(p|h|li)"))
        text = ""
        for block in paragraphs:
            for s in block.stripped_strings:
                text += str(s) + " "
        print(text)

    tags_html = soup.find("div", class_="article__tags__container")
    if tags_html:
        tags = []
        for tag in map(lambda s: str(s.string), tags_html.find_all("a")):
            tags.append(tag)
        print(tags)
            
dl_vk_data(-25232578, parse_rbc)
# Out:
# --------------------------------------------------
# Главные новости РБК в прямом эфире. На канале представлены главные новости политики, экономики и бизнеса России, комментарии аналитиков, финансовые данные с российских и мировых биржевых систем.
# Эксклюзивные интервью с ведущими политиками и бизнесменами; Аналитические обзоры, прогнозы и комментарии экспертов.
#
# Смотрите нас в RUTUBE: https://rutube.ru/channel/24141691/
# Смотрите нас в VK: https://vk.com/rbc
# Смотрите нас в Яндекс.Дзен: https://zen.yandex.ru/rbc.ru
# --------------------------------------------------
# Союз российских пивоваров считает, что транснациональные компании в России могут применять высокоактивные ферментные препараты и катализаторы для ускоренного пивоварения
# https://www.rbc.ru/business/21/02/2023/63f462db9a79473f2d6af43f?utm_source=vk&utm_medium=social&utm_campaign=preview
# Российские пивовары попросили разобраться с варкой пива за три дня
# Союз российских пивоваров считает, что транснациональные компании в России могут применять высокоактивные ферментные препараты и катализаторы для ускоренного пивоварения Фото: Martin Divisek / EPA / ТАСС Союз российских пивоваров (СРП) попросил руководителя Росалкогольрегулирования Игоря Алешина разобраться в ситуации с глобальными пивоваренными компаниями в связи с ускорением ими производства, пишет газета «Коммерсантъ» со ссылкой на копию письма председателя совета СРП Даниила Бримана от 20 февраля. Регулятор подтвердил получение обращения. По словам Бримана, в феврале представитель AB InBev Efes (выпускает пиво Velkopopovicky Kozel, «Сибирская корона», «Клинское» и др.) заявил на одном из совещаний, что в портфеле компании в стране есть пиво, которое варится за три дня. Хотя, согласно приказу Росалкогольрегулирования, минимальный срок производства этого напитка должен составлять от 6,5 до 18 суток в зависимости от оборудования. «Коммерсантъ» узнал об идее повысить пошлину на импортное пиво adv.rbc.ru adv.rbc.ru adv.rbc.ru По мнению СРП, транснациональные компании в России могут применять высокоактивные ферментные препараты и катализаторы для ускоренного пивоварения, что позволяет увеличить объем производства и снизить себестоимость пива. Присутствие на рынке напитка, который варится за три дня, российские пивовары считают главной причиной «демпинга» и предлагают отнести выпускаемое по ускоренным технологиям пиво к слабоалкогольным зерновым напиткам, а также повысить акциз на него. adv.rbc.ru adv.rbc.ru adv.rbc.ru В Ассоциации производителей пива (AB InBev Efes, «Балтика», Heineken) отвергли претензии СРП, заявив, что те не имеют «ничего общего с действительностью и вводят в заблуждение потребителей». Там объяснили, что у некоторых брендов процесс дображивания пива имеет более короткий срок благодаря использованию современного оборудования, но все производство занимает не менее семи дней. АПП предлагала регулятору сократить минимальный срок дображивания с 18 до одного дня «для обеспечения достоверности расчета мощности, чтобы исключить занижение показателя», сообщили в ассоциации. Прошлой осенью правительство ввело обязательную маркировку пива. Так, маркировать его в кегах (пластиковая или металлическая емкость) потребуется уже с 1 апреля, в стеклянной таре или полимерной упаковке — с 1 октября этого года. Для всех остальных видов упаковки правило вступит в силу с 15 января 2024-го.
# ['пивовары', 'пиво']
# --------------------------------------------------
# Убытки верфей от постройки судов для вылова рыбы достигли 42 млрд руб. Чтобы решить проблему, может понадобиться программа финансового оздоровления предприятий судостроения, считает глава Росрыболовства Илья Шестаков
# https://www.rbc.ru/business/21/02/2023/63f3bdb79a794717bb8611fc?utm_source=vk&utm_medium=social&utm_campaign=preview
# В Росрыболовстве признали убытки верфей на ₽42 млрд
# Убытки верфей от постройки судов для вылова рыбы достигли 42 млрд руб. Чтобы решить проблему, может понадобиться программа финансового оздоровления предприятий судостроения, считает глава Росрыболовства Илья Шестаков Илья Шестаков (Фото: Андрей Любимов / РБК) Суммарный убыток российских верфей от строительства 105 судов для вылова рыбы и краба «огромный» и составляет около 42 млрд руб., рассказал в интервью РБК глава Росрыболовства Илья Шестаков. Строительство 64 рыбопромысловых и 41 краболовного судов в рамках первого этапа программы инвестквот и крабовых аукционов с инвестиционными обязательствами началось в 2018 году. Из этих судов спустя пять лет, к февралю, заказчикам передано в общей сложности лишь 14 судов: десять рыбопромысловых и четыре краболовных. Глава Росрыболовства — РБК: «Затраты рыбаков на цене рыбы не отражаются» adv.rbc.ru adv.rbc.ru adv.rbc.ru По словам Шестакова, оставшиеся 37 краболовов будут достроены в течение пяти лет, то есть не позднее 2027 года. Но со строительством рыбопромыслового флота «есть серьезные проблемы». «Они начались еще до санкций, и в какой-то степени их можно оправдать пандемией [COVID-19]. Но в большей степени сложности были связаны с отсутствием у верфей на начальном этапе программы нужных компетенций, и у них возникли трудности при строительстве рыбопромыслового флота по коммерческим заказам в сжатые сроки и по фиксированной цене», — объяснил глава Росрыболовства. Предприятия судостроения взяли заказы, но договорные обязательства с рыбаками «прописали плохо и просчитались»: «Сейчас верфи декларируют по промысловым судам огромные убытки — около 42 млрд руб.», — добавил Шестаков. adv.rbc.ru adv.rbc.ru adv.rbc.ru Минпромторг оценил строительство суперверфи «Росатома» в ₽200 млрд При этом, по информации ведомства, чтобы получить суда, некоторые рыбопромышленники, несмотря на заключенные договора, идут навстречу верфям и согласовывают изменение стоимости или продление сроков строительства. Чтобы решить проблему убытков, возможно, придется вводить «какую-то программу финансового оздоровления» верфей, полагает Шестаков. Но с этим будут разбираться непосредственно Минпромторг и Объединенная судостроительная корпорация (ОСК), замечает он. РБК направил запросы в пресс-службы Минпромторга и ОСК. По словам главы Росрыболовства, программа модернизации флота нужна в том числе, чтобы решить проблему старения служащих на флоте и привлечения в отрасль новых кадров. Сейчас примерно 70% работников экипажей рыболовецких судов старше 50 лет. «Работа на промысле тяжелая. Рыбаки уходят в море на три месяца и более, а на старых судах условия быта, мягко говоря, не очень комфортные. Понятно, что молодые специалисты после окончания учебного заведения вряд ли выберут такую профессию», — замечает Шестаков. При этом в рыбопромышленных компаниях, получивших новые суда, «текучки кадров нет», а конкурс на вакансии высокий, утверждает чиновник. Госпрограмма, направленная на модернизацию рыбопромыслового флота, развитие рыбоперерабатывающих предприятий и береговой инфраструктуры, была предложена в 2015 году. «По сути мы дали рыбакам квоты в обмен на то, чтобы нивелировать стоимость строительства для них судов в России и загрузить отечественные верфи», — вспоминает Шестаков. Счетная палата не поддержала продолжение крабовых аукционов Первый этап распределения инвестиционных квот начался в 2017 году: тогда предприятиям было выделено 20% от общего допустимого улова сельди и минтая под обязательства постройки новых рыболовных судов на российских верфях и строительства перерабатывающих заводов. В 2019 году в России впервые за 15 лет прошли крабовые аукционы: на торги было выставлено 50% квот на добычу краба, а получившие их предприятия обязаны были построить новые суда-краболовы. Второй этап реформы инвестквот запланирован на 2023 год: на аукционах планируется распределить 20% от общего допустимого улова минтая и сельди на Дальнем Востоке, а также остальные 50% квот на добычу краба.
# ['Росрыболовство', 'Илья Шестаков', 'судостроение', 'вылов рыбы', 'рыба', 'краболовы', 'суда', 'верфи', 'судоверфь']
# --------------------------------------------------
# За половую связь с животным теперь будут наказывать только в том случае, если оно получило травмы
# https://www.rbc.ru/politics/21/02/2023/63f455969a79473a30c75ada?utm_source=vk&utm_medium=social&utm_campaign=preview
# Испания декриминализировала секс с животными при отсутствии вреда
# За половую связь с животным теперь будут наказывать только в том случае, если оно получило травмы Фото: Justin Sullivan / Getty Images В Испании сексуальные отношения с животным будут считаться преступлением, если только причиняют ему вред, пишет издание Libertad Digital о поправках в Уголовный кодекс страны. Половая связь, не причинившая вред здоровью животного, перестает подлежать уголовному наказанию. Поправки в УК касаемо жестокого обращения с животными были одобрены конгрессом 9 февраля. Сексуальная эксплуатация животных в Испании впервые стала наказуемой в 2015 году. Тогда зоофилия была включена в УК в качестве нового преступления, так как парламентарии сочли, что животные, как и дети, не способны давать согласие на интимные отношения. Сексуальные отношения с домашними животными, как и жестокое обращение, согласно ст. 337.1 УК наказывалось тюремным заключением от трех месяцев до одного года. Reuters узнал о расследовании в отношении компании Маска из-за животных Теперь в УК появится статья «Преступления против животных», в которой говорится, что уголовным преступлением считаются любые действия (в том числе сексуальные отношения), которые причиняют вред животному и из-за которых ему требуется лечение. Иными словами, зоофилия перестает быть отдельным преступлением, пишет издание. За половую связь с животным теперь будут наказывать только в том случае, если оно получило травмы. Максимальное наказание за это — тюремное заключение от трех месяцев до полутора лет.
# ['Испания', 'зоофилия']
# --------------------------------------------------
# Новое землетрясение в Турции. Итоги визита Байдена в Киев

# %%
def parse_ria(html):
    soup = BeautifulSoup(html)
    title_html = soup.find("div", class_="article__title")
    second_title_html = soup.find("h1", class_="article__second-title")
    if title_html and second_title_html:
        title = str(title_html.string) + ". " + str(second_title_html.string)
        print(title)
        
    article_html = soup.find_all("div", class_="article__text")
    if article_html:
        article = ""
        for block in article_html:
            for s in block.stripped_strings:
                article += str(s) + " "
        print(article)
        
    tags_html = soup.find_all("a", class_="article__tags-item")
    if tags_html:
        tags = []
        for tag in tags_html:
            tags.append(str(tag.string))
        print(tags)
    
dl_vk_data(-15755094, parse_ria)
# Out:
# --------------------------------------------------
# Волонтеры сообщества [club212156263|"Неравнодушные"] помогают людям в зоне СВО. Они не только привозят гумпомощь пострадавшим, но и оказывают психологическую поддержку. Активисты рассказывают, что для таких людей самое главное - выговориться и быть услышанным. Для многих волонтеров те, кому они помогают, стали уже настоящей семьей. А главная цель движения "Неравнодушные" - дать понять тем, кто нуждается в поддержке, что они не одиноки в своей беде, что за ними целая страна и огромный тыл.
# --------------------------------------------------
# США и Евросоюз так и не определились, чем, с их точки зрения, должны закончиться боевые действия на Украине. В НАТО нет единства по этому вопросу. Кто на Западе наиболее агрессивно настроен по отношению к Москве и с чем это связано — в нашем материале.
# https://ria.ru/20230221/ukraina-1853207020.html
# МОСКВА, 21 фев — РИА Новости, Михаил Катков. США и Евросоюз так и не определились, чем, с их точки зрения, должны закончиться боевые действия на Украине. В НАТО нет единства по этому вопросу. Кто на Западе наиболее агрессивно настроен по отношению к Москве и с чем это связано — в материале РИА Новости. В конце января в интервью The Washington Post глава ГУР Минобороны Украины Кирилл Буданов заявил, что к лету ВСУ захватят Крым. А изданию Wirtualna Polska он сказал, что Россию разделят на несколько частей и введут внешнее управление. Секретарь СНБО Алексей Данилов 11 февраля опубликовал в "Украинской правде" статью. По его мнению, настоящая победа Киева — когда Россия исчезнет. Он уверен, что альтернативы нет, поскольку русские — не немцы, которых перевоспитали после Второй мировой войны. Ну а для начала Москву надо лишить ядерного оружия. В Евросоюзе под патронажем украинских властей прошло несколько заседаний форума российских сепаратистов. "Представители" малых народов с трибуны рассказывали, как в далеком прошлом Москва лишила их свободы. Если этих людей на родине и поддерживают, то максимум несколько человек. Но это нисколько не мешает организаторам преподносить мероприятия как решающие для будущего страны. Издание Politico со ссылкой на главу Госдепа Энтони Блинкена утверждает, что США не рекомендуют ВСУ вторгаться в Крым. Но, конечно, окончательное решение — за Киевом. Заместитель госсекретаря Виктория Нуланд сообщила, что в Вашингтоне думают о том, как не только сейчас помочь Украине, но и обезопасить ее в будущем. В частности, Киеву понадобятся мощные ПВО и армия. Демилитаризация Крыма — обязательное условие. После неизбежного "стратегического поражения Путина" у Москвы не останется шансов на реванш. Бывший спецпредставитель США по Украине Курт Волкер полагает, что необязательно захватывать Крым: достаточно его изолировать. Для этого надо ликвидировать сухопутный коридор на полуостров, Керченский мост и военно-морскую базу в Севастополе. Тем не менее в Пентагоне сомневаются в возможностях Киева. Председатель Объединенного комитета начальников штабов генерал Марк Милли 20 января признал, что ВСУ будет "очень и очень сложно" отбить те территории, которые Россия взяла под контроль. Заместитель главы МИД Польши Павел Яблонский в эфире RMF FM сообщил, что наихудший итог боевых действий — если Москва сможет сохранить лицо. Президент Анджей Дуда выразил готовность "строить железный занавес до самых облаков", лишь бы отгородиться от русских. Главы Франции и Германии Эммануэль Макрон и Олаф Шольц не так однозначны. Оба твердят, что Россия должна проиграть и ради этого они станут поддерживать Киев столько, сколько потребуется. Вместе с тем Париж и Берлин приняли "мирный план" Зеленского из десяти пунктов лишь как основу для дальнейших международных дискуссий. Москва вообще отказывается обсуждать украинские "предложения", поскольку они не учитывают сложившихся реалий. Макрон допускает гарантии безопасности для России. В частности, надо снять все вопросы о дальнейшем расширении НАТО. Русских нельзя унижать, подчеркивает он, потому что сотрудничество придется восстанавливать. А генсек Североатлантического блока Йенс Столтенберг уверен: Киев присоединится к альянсу вскоре после победы над Москвой. Зеленский придерживается того же мнения. Выступая на Мюнхенской конференции по безопасности, он отметил, что у Украины нет альтернативы вступлению в Евросоюз и НАТО. И только один премьер-министр Венгрии Виктор Орбан критикует позицию ЕС в украинском конфликте. Разница в подходах представителей Запада к России пока незначительна, но расхождения могут усилиться. Главный редактор журнала "Россия в глобальной политике" Федор Лукьянов отмечает, что европейцы и американцы произносят почти одни и те же слова. "Кто-то говорит, что Украина должна победить, но Россия не должна быть разгромлена, а кто-то хочет все вместе. Для Москвы одно от другого не отличается", — констатирует он. Наиболее агрессивно настроены американцы. "Из-за удаленности от пол ...
# ['Россия', 'Украина', 'Киев', 'Эммануэль Макрон', 'Федор Лукьянов', 'Алексей Данилов', 'Вооруженные силы Украины', 'НАТО', 'Совет национальной безопасности и обороны Украины', 'Политика']
# --------------------------------------------------
# Также должны сократиться сроки привлечения к ответственности за уклонение от уплаты налогов - с десяти до шести лет.
# https://ria.ru/20230221/kabmin-1853316078.html
# СМИ: правительство одобрило отказ от уголовных дел при оплате пеней. "Коммерсантъ": правительство одобрило отказ от уголовных дел при оплате налоговой недоимки
# МОСКВА, 21 фев — РИА Новости. Правительственная комиссия одобрила поправки к Уголовному кодексу России, которые должны исключать уголовное преследование, если предприниматель полностью оплатил налоговые недоимки и пени, пишет газета "Коммерсантъ" со ссылкой на источник в правительстве. Как пишет издание, поправки обязывают компетентные органы вынести постановление об отказе в возбуждении уголовного дела или его прекращении, если предприниматель вышел из тени и исполнил все свои налоговые обязательства. Также, по данным газеты, должны сократиться сроки привлечения к ответственности за уклонение от уплаты налогов — с десяти до шести лет. В начале февраля прошлого года руководитель экспертного центра " Деловой России " по уголовно-правовой политике и исполнению судебных актов Екатерина Авдеева затронула соответствующую проблему на встрече с президентом Владимиром Путиным . В апреле Путин поручил правительству, Верховному суду, Генпрокуратуре , Следственному комитету, администрации президента при участии "Деловой России" проработать этот вопрос.
# ['Экономика', 'Россия', 'Владимир Путин', 'Деловая Россия', 'Госдума РФ', 'Генеральная прокуратура РФ']
# --------------------------------------------------
#
# https://ria.ru/20230221/yaponiya-1853319576.html
# На берегу в японской Сидзуоке обнаружили неизвестный шар. Daiichi TV: на берегу в японской Сидзуоке обнаружили неизвестный шар диаметром 1,5 метра
# ТОКИО, 21 фев — РИА Новости. В Японии на пляже нашли подозрительный шар диаметром около полутора метров, предположительно, из металла, сообщил телеканал Daiichi TV . Выброшенный на берег предмет обнаружила жительница города Хамамацу префектуры Сидзуока на пляже Энсюхама. Женщина позвонила в полицию около 8:45 по местному времени (2:45 мск). Доступ на место происшествия закрыли, движение в районе строго регулируется. Сейчас неизвестный объект проверяют специалисты. Фотографии шара направили экспертам из сил самообороны Японии и береговой охраны. Другой информации пока не поступало.
# ['В мире', 'Сидзуока (префектура)', 'Хамамацу', 'Япония']
# --------------------------------------------------
# Бывший президент США пообещал, что в случае переизбрания на пост главы государства "в ту же ночь" позвонит Путину и Зеленскому для проведения встречи с целью разрешения конфликта на Украине.
#
# "Я гарантирую, что смогу разрешить этот вопрос… Мы заключим сделку в течение 24 часов", - заявил он.

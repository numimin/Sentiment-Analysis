# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\egorf\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\egorf\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
# !pip install html5lib
# !pip install PyQt5
# Out:
# Requirement already satisfied: html5lib in c:\users\egorf\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in c:\users\egorf\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\egorf\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Collecting PyQt5
#   Downloading PyQt5-5.15.9-cp37-abi3-win_amd64.whl (6.8 MB)
#      ---------------------------------------- 6.8/6.8 MB 4.6 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.1-cp39-cp39-win_amd64.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 4.5 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# ERROR: Could not install packages due to an OSError: [WinError 5] \u041e\u0442\u043a\u0430\u0437\u0430\u043d\u043e \u0432 \u0434\u043e\u0441\u0442\u0443\u043f\u0435: 'C:\\Users\\egorf\\anaconda3\\Lib\\site-packages\\PyQt5\\QtCore.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import json
from bs4 import BeautifulSoup
import urllib.request
import re
from PyQt5.QtWidgets import QApplication
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEnginePage
import sys
import datetime

class Client(QWebEnginePage):
    
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEnginePage.__init__(self)
        self.loadFinished.connect(self.on_page_load)
        self.setUrl(QUrl(url))
        self.app.exec_()
        
    def on_page_load(self):
        self.app.quit()

def dl_vk_data(group_id, parse, offset=0, count=5, use_js_emulator=False, encoding='utf-8'):
    with urllib.request.urlopen(f'https://api.vk.com/method/wall.get?access_token=247f3d70247f3d70247f3d70d6276dfd5c2247f247f3d70478c4cc7443965779421d6d7&owner_id={group_id}&v=5.131&offset={offset}&count={count}') as f:
        json_string = f.read().decode('utf-8')
    json_res = json.loads(json_string)['response']
    for item in json_res['items']:
        print("-" * 50)
        text = item['text']
        print(text)
        for attachment in item['attachments']:
            link = attachment.get('link')
            if not link:
                continue
            url = link['url']
            print(url)
            if use_js_emulator:
                Client(url).toHtml(lambda arg: print(arg))
            else:
                with urllib.request.urlopen(url) as f:
                    if encoding == 'utf-8':
                        html = f.read().decode(encoding)
                    else:
                        html = f.read()
                data = parse(url, html)
                if not data:
                    continue
                (title, article, tags, date) = data
                print(f"Title: {title}, Date: {date}, Tags: {tags}")
                print(article)

# %%
def parse_title_rbc(soup):
    title_html = soup.find("div", class_="article__header__title")
    if not title_html:
        return ""
    
    return str(title_html.h1.string).strip()

def parse_article_rbc(soup):
    article_html = soup.find("div", class_="article__text")
    if not article_html:
        return ""
    
    paragraphs = article_html.find_all(re.compile("(p|h|li)"))
    article = ""
    for block in paragraphs:
        for s in block.stripped_strings:
            article += str(s) + " "
    return article

def parse_tags_rbc(soup):
    tags_html = soup.find("div", class_="article__tags__container")
    if not tags_html:
        return []
    
    tags = []
    for tag in map(lambda s: str(s.string), tags_html.find_all("a")):
        tags.append(tag)
    return tags

def parse_date_rbc(url):
    date = re.findall("[0-9]+/", url)
    if len(date) != 2:
        return None
    
    year = int(date[2][:-1])
    month = int(date[1][:-1])
    day = int(date[0][:-1])
    return datetime.datetime(year, month, day)

def parse_rbc(url, html):
    soup = BeautifulSoup(html)
    title = parse_title_rbc(soup)
    article = parse_article_rbc(soup)
    tags = parse_tags_rbc(soup)
    date = parse_date_rbc(url)
    
    return (title, article, tags, date)
            
dl_vk_data(-25232578, parse_rbc)
# Out:
# --------------------------------------------------
# Главные новости РБК в прямом эфире. На канале представлены главные новости политики, экономики и бизнеса России, комментарии аналитиков, финансовые данные с российских и мировых биржевых систем.
# Эксклюзивные интервью с ведущими политиками и бизнесменами; Аналитические обзоры, прогнозы и комментарии экспертов.
#
# Смотрите нас в RUTUBE: https://rutube.ru/channel/24141691/
# Смотрите нас в VK: https://vk.com/rbc
# Смотрите нас в Яндекс.Дзен: https://zen.yandex.ru/rbc.ru
# --------------------------------------------------
# Страны Запада, хотя обещали решить проблемы жителей Донбасса, «закрывали глаза» на них, заявил президент Владимир Путин
# https://www.rbc.ru/politics/21/02/2023/63f48a689a79474fd6f102fb?utm_source=vk&utm_medium=social&utm_campaign=preview
# Title: Путин обвинил Запад в «подлоге и жестокой лжи», Date: None, Tags: ['Владимир Путин', 'Донбасс', 'Запад']
# Россия делала все, чтобы решить проблему Донбасса миром, но «за ее спиной готовился другой сценарий», заявил Путин. Он обвинил Запад в невыполнении обещаний Владимир Путин (на экране) (Фото: РБК) Страны Запада, хотя обещали решить проблемы жителей Донбасса, «закрывали глаза» на них, заявил президент Владимир Путин, выступая с посланием к Федеральному собранию. «Обещание западных правителей, их заявление о стремлении к миру на Донбассе обернулось подлогом, жестокой ложью. Они просто тянули время, занимались крючкотворством», — сказал он. По утверждению президента, они игнорировали «политические убийства и репрессии киевского режима против неугодных». Путин заявил, что Россия делала все возможное, чтобы решить проблему Донбасса мирными средствами, и вела переговоры. «Но за нашей спиной готовился совсем другой сценарий», — считает он. adv.rbc.ru adv.rbc.ru adv.rbc.ru Путин заявил, что вся планета утыкана базами США adv.rbc.ru adv.rbc.ru adv.rbc.ru Президент ранее не раз говорил , что «помощь людям Донбасса» является главной целью российской военной операции. «Именно избавить людей от этих страданий, от этого геноцида является основной, главной причиной, побудительным мотивом и целью военной операции, которую мы начали в Донбассе и на Украине», — заявлял он в марте прошлого года во время своего выступления в «Лужниках» на концерте в честь присоединения Крыма. Министр иностранных дел России Сергей Лавров прошлой весной также называл целью спецоперации обеспечение безопасности восточной Украины и России. Он, также как и Путин, возложил на Запад ответственность за ухудшение отношений Москвы и Киева.
# --------------------------------------------------
# В первом полугодии американский рынок ждет распродажа, а индекс S&P500 может обвалиться более чем на четверть, прогнозируют в банке
# https://quote.ru/news/article/63f474409a79474613d71005?utm_source=vk&utm_medium=social&utm_campaign=preview
# Title: , Date: None, Tags: []
#
# --------------------------------------------------
# По его словам, послание президента продлится по меньшей мере час. Большая его часть будет посвящена теме военной операции на Украине, «ее предопределенности и необходимости с точки зрения наших национальных интересов», отметил пресс-секретарь
# https://www.rbc.ru/rbcfreenews/63f483b39a79474d89f4ca7e?utm_source=vk&utm_medium=social&utm_campaign=preview
# Title: Песков заявил, что Путин в послании даст видение движения России вперед, Date: None, Tags: ['Владимир Путин', 'Дмитрий Песков']
# Владимир Путин (Фото: Максим Шипенков / EPA / ТАСС) Президент России Владимир Путин в послании даст оценку ситуации в экономике и продемонстрирует видение того, как страна будет двигаться вперед, сообщил пресс-секретарь президента Дмитрий Песков. Его слова приводит «РИА Новости» . «Президент даст свою оценку тому, как развивалась наша экономика, как ей удалось выстоять, остаться стоять на ногах», — сказал Песков. Он отметил, что Путин «даст свое видение того, как мы будем двигаться вперед». «А мы будем двигаться вперед, в этом нет сомнений», — добавил представитель Кремля. Послание Владимира Путина Федеральному собранию. Онлайн adv.rbc.ru adv.rbc.ru adv.rbc.ru По его словам, послание президента продлится по меньшей мере час. Большая его часть будет посвящена теме военной операции на Украине, «ее предопределенности и необходимости с точки зрения наших национальных интересов», отметил пресс-секретарь. Он также назвал послание «абсолютно авторским продуктом президента». adv.rbc.ru adv.rbc.ru adv.rbc.ru Президент России Владимир Путин выступит с посланием Федеральному собранию в 12:00 во вторник, 21 февраля. Послание пройдет в Гостином дворе.
# --------------------------------------------------
# Послание Владимира Путина Федеральному собранию. Прямая трансляция

# %%
def parse_title_ria(soup):
    title_html = soup.find("div", class_="article__title")
    if not title_html:
        return ""
    second_title_html = soup.find("h1", class_="article__second-title")
    if not second_title_html:
        return ""
    
    return str(title_html.string) + ". " + str(second_title_html.string)

def parse_article_ria(soup):
    article_html = soup.find_all("div", class_="article__text")
    if not article_html:
        return ""
    
    article = ""
    for block in article_html:
        for s in block.stripped_strings:
            article += str(s) + " "
    return article

def parse_tags_ria(soup):
    tags_html = soup.find_all("a", class_="article__tags-item")
    if not tags_html:
        return []
    
    tags = []
    for tag in tags_html:
        tags.append(str(tag.string))
    return tags

def parse_date_ria(url):
    date = re.search("/[0-9]+/", url).group()[1:-1]
    year = int(date[0:4])
    month = int(date[4:6])
    day = int(date[6:8])
    return datetime.datetime(year, month, day)
    
def parse_ria(url, html):
    soup = BeautifulSoup(html)
    title = parse_title_ria(soup)
    article = parse_article_ria(soup)
    tags = parse_tags_ria(soup)
    date = parse_date_ria(url)
    
    return (title, article, tags, date)
    
dl_vk_data(-15755094, parse_ria, count=10)
# Out:
# --------------------------------------------------
# #ПРЯМАЯТРАНСЛЯЦИЯ
# Послание Владимира Путина Федеральному Собранию.
# --------------------------------------------------
# ⚡⚡⚡
# ️Те, кто встал на путь предательства России, понесет ответственность по закону, отметил глава государства.
# https://ria.ru/20230221/poslanie-1853328331.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Владимир Путин', 'Россия', 'Послание президента Федеральному собранию 21 февраля 2023 года']
#
# --------------------------------------------------
# ⚡⚡⚡ Ответственность за разжигание конфликта на Украине лежит на западных элитах, подчеркнул президент. При этом Запад хочет перевести конфликт в фазу глобального противостояния.
# https://ria.ru/20230221/poslanie-1853328331.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Владимир Путин', 'Россия', 'Послание президента Федеральному собранию 21 февраля 2023 года']
#
# --------------------------------------------------
# ⚡⚡⚡
# https://ria.ru/20230221/poslanie-1853328331.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Владимир Путин', 'Россия', 'Послание президента Федеральному собранию 21 февраля 2023 года']
#
# --------------------------------------------------
# ⚡⚡⚡ Запад форсировал проект "анти-Россия" на Украине, поддержав кровавый переворот, добавил он.
# https://ria.ru/20230221/poslanie-1853328331.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Владимир Путин', 'Россия', 'Послание президента Федеральному собранию 21 февраля 2023 года']
#
# --------------------------------------------------
# ⚡⚡⚡ Президент подчеркнул, что Россия аккуратно и последовательно будет решать задачи спецоперации .
# https://ria.ru/20230221/poslanie-1853328331.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Владимир Путин', 'Россия', 'Послание президента Федеральному собранию 21 февраля 2023 года']
#
# --------------------------------------------------
# Сегодня в 12:00 по московскому времени Владимир Путин обратится с посланием к Федеральному собранию. Следите за новостями в нашем онлайн-репортаже:
# https://ria.ru/20230221/poslanie-1853328331.html
# --------------------------------------------------
# В Италии протестуют против поставок оружия на Украину. Десятки людей вышли на улицы Пизы с лозунгами "Бросить оружие, поднять заработную плату". Митингующие жалуются на рост цен в стране и маленькую заработную плату. Также итальянцы высказались за мирное разрешение конфликта и переговоры.
# --------------------------------------------------
# Сейчас на белорусско-польской границе остался лишь один пассажирский пункт пропуска Брест-Тересполь и ни одного грузового.
# https://ria.ru/20230221/granitsa-1853338586.html
# Title: Польша готова полностью закрыть движение через границу с Белоруссией. МИД Польши сообщил о готовности полностью закрыть движение через границу с Белоруссией, Date: 2023-02-21 00:00:00, Tags: ['В мире', 'Польша', 'Белоруссия']
# ВАРШАВА, 21 фев — РИА Новости. Польша готова полностью закрыть границу с Белоруссией, заявил замминистра иностранных дел республики Павел Яблоньский в эфире Польского радио . При этом Яблоньский подчеркнул, что решения о закрытии КПП не принимаются исключительно по политическим мотивам. По его словам, в Варшаве понимают, что есть перевозчики и товары, которые можно перевозить через границу. Но как только анализ ситуации покажет, что есть растущая угроза безопасности, то такое решение может быть принято, заключил Яблоньский. С 10 февраля по распоряжению министра внутренних дел Польши Мариуша Каминьского в "интересах государственной безопасности" прекращено движение через КПП "Берестовица — Бобровники". Вечером 21 февраля КПП "Козловичи — Кукурыки" закроется для проезда грузовиков, зарегистрированных в ЕС и Европейской ассоциации свободной торговли. Таким образом, на белорусско-польской границе останется лишь один пассажирский пункт пропуска "Брест — Тересполь" и ни одного грузового. В ответ Минск изменил режим перемещения польских грузоперевозчиков: они смогут въезжать на территорию Белоруссии и покидать ее исключительно через белорусско-польский участок границы. В Варшаве предупредили, что введут идентичные ограничения в отношении белорусских перевозчиков.
# --------------------------------------------------
# США и Евросоюз так и не определились, чем, с их точки зрения, должны закончиться боевые действия на Украине. В НАТО нет единства по этому вопросу. Кто на Западе наиболее агрессивно настроен по отношению к Москве и с чем это связано — в нашем материале.
# https://ria.ru/20230221/ukraina-1853207020.html
# Title: , Date: 2023-02-21 00:00:00, Tags: ['Россия', 'Украина', 'Киев', 'Эммануэль Макрон', 'Федор Лукьянов', 'Алексей Данилов', 'Вооруженные силы Украины', 'НАТО', 'Совет национальной безопасности и обороны Украины', 'Политика']
# МОСКВА, 21 фев — РИА Новости, Михаил Катков. США и Евросоюз так и не определились, чем, с их точки зрения, должны закончиться боевые действия на Украине. В НАТО нет единства по этому вопросу. Кто на Западе наиболее агрессивно настроен по отношению к Москве и с чем это связано — в материале РИА Новости. В конце января в интервью The Washington Post глава ГУР Минобороны Украины Кирилл Буданов заявил, что к лету ВСУ захватят Крым. А изданию Wirtualna Polska он сказал, что Россию разделят на несколько частей и введут внешнее управление. Секретарь СНБО Алексей Данилов 11 февраля опубликовал в "Украинской правде" статью. По его мнению, настоящая победа Киева — когда Россия исчезнет. Он уверен, что альтернативы нет, поскольку русские — не немцы, которых перевоспитали после Второй мировой войны. Ну а для начала Москву надо лишить ядерного оружия. В Евросоюзе под патронажем украинских властей прошло несколько заседаний форума российских сепаратистов. "Представители" малых народов с трибуны рассказывали, как в далеком прошлом Москва лишила их свободы. Если этих людей на родине и поддерживают, то максимум несколько человек. Но это нисколько не мешает организаторам преподносить мероприятия как решающие для будущего страны. Издание Politico со ссылкой на главу Госдепа Энтони Блинкена утверждает, что США не рекомендуют ВСУ вторгаться в Крым. Но, конечно, окончательное решение — за Киевом. Заместитель госсекретаря Виктория Нуланд сообщила, что в Вашингтоне думают о том, как не только сейчас помочь Украине, но и обезопасить ее в будущем. В частности, Киеву понадобятся мощные ПВО и армия. Демилитаризация Крыма — обязательное условие. После неизбежного "стратегического поражения Путина" у Москвы не останется шансов на реванш. Бывший спецпредставитель США по Украине Курт Волкер полагает, что необязательно захватывать Крым: достаточно его изолировать. Для этого надо ликвидировать сухопутный коридор на полуостров, Керченский мост и военно-морскую базу в Севастополе. Тем не менее в Пентагоне сомневаются в возможностях Киева. Председатель Объединенного комитета начальников штабов генерал Марк Милли 20 января признал, что ВСУ будет "очень и очень сложно" отбить те территории, которые Россия взяла под контроль. Заместитель главы МИД Польши Павел Яблонский в эфире RMF FM сообщил, что наихудший итог боевых действий — если Москва сможет сохранить лицо. Президент Анджей Дуда выразил готовность "строить железный занавес до самых облаков", лишь бы отгородиться от русских. Главы Франции и Германии Эммануэль Макрон и Олаф Шольц не так однозначны. Оба твердят, что Россия должна проиграть и ради этого они станут поддерживать Киев столько, сколько потребуется. Вместе с тем Париж и Берлин приняли "мирный план" Зеленского из десяти пунктов лишь как основу для дальнейших международных дискуссий. Москва вообще отказывается обсуждать украинские "предложения", поскольку они не учитывают сложившихся реалий. Макрон допускает гарантии безопасности для России. В частности, надо снять все вопросы о дальнейшем расширении НАТО. Русских нельзя унижать, подчеркивает он, потому что сотрудничество придется восстанавливать. А генсек Североатлантического блока Йенс Столтенберг уверен: Киев присоединится к альянсу вскоре после победы над Москвой. Зеленский придерживается того же мнения. Выступая на Мюнхенской конференции по безопасности, он отметил, что у Украины нет альтернативы вступлению в Евросоюз и НАТО. И только один премьер-министр Венгрии Виктор Орбан критикует позицию ЕС в украинском конфликте. Разница в подходах представителей Запада к России пока незначительна, но расхождения могут усилиться. Главный редактор журнала "Россия в глобальной политике" Федор Лукьянов отмечает, что европейцы и американцы произносят почти одни и те же слова. "Кто-то говорит, что Украина должна победить, но Россия не должна быть разгромлена, а кто-то хочет все вместе. Для Москвы одно от другого не отличается", — констатирует он. Наиболее агрессивно настроены американцы. "Из-за удаленности от пол ...

# %%
def parse_title_interfax(soup):
    title_html = soup.find("h1", itemprop="headline")
    if not title_html:
        return ""
    return title_html.string

def parse_article_interfax(soup):
    article_html = soup.find("article", itemprop="articleBody")
    if not article_html:
        return ""
    
    article = ""
    for p in article_html.find_all("p"):
        for s in p.stripped_strings:
            article += str(s) + " "
    return article

def parse_tags_interfax(soup):
    tags_html = soup.find("div", class_="textMTags")
    if not tags_html:
        return []
    
    tags = []
    for a in tags_html.find_all("a"):
        tags.append(str(a.string))
    return tags

def parse_date_interfax(soup):
    date_html = soup.find("aside", class_="textML")
    if not date_html:
        return None
    date = date_html.find("time")['datetime']
    return datetime.datetime.strptime(date, "%Y-%m-%dT%H:%M")

def parse_interfax(url, html):
    soup = BeautifulSoup(html)
    title = parse_title_interfax(soup)
    article = parse_article_interfax(soup)
    tags = parse_tags_interfax(soup)
    date = parse_date_interfax(soup)
        
    return (title, article, tags, date)
    
dl_vk_data(-24228287, parse_interfax, encoding='koi8')
# Out:
# --------------------------------------------------
#
# https://www.interfax.ru/business/887124
# Title: Сокращение добычи нефти в РФ с марта планируется от уровня января, Date: 2023-02-21 11:51:00, Tags: ['Александр Новак']
# Москва. 21 февраля. INTERFAX.RU - Снижение добычи нефти в РФ на 500 тыс. б/с в марте планируется от январского уровня производства, обсуждается вариант пропорционального распределения объемов сокращения между нефтекомпаниями, сообщил "Интерфаксу" вице-премьер РФ Александр Новак. "Рассматривается предложение (снижения добычи нефти - ИФ) именно пропорционально (между компаниями - ИФ) . Базой (снижения - ИФ) скорее всего (будет - ИФ) январь, потому что февральской добычи фактически нет", - сказал он. Новак также заявил журналистам, что Россия приняла решение о сокращении добычи нефти на 500 тысяч баррелей в сутки только на март, далее будет решать в зависимости от ситуации на рынке. "Мы будем смотреть, как будет развиваться ситуация на рынке, от этого будут приниматься решения. Сейчас пока решение принято на март", - сказал вице-премьер РФ. Как сообщалось, РФ в марте намерена "добровольно" снизить нефтепроизводство на 500 тыс. б/с, снижение коснется только нефти. По словам Новака, решение было принято без международных консультаций, оно будет способствовать восстановлению рыночных отношений на фоне введения ограничений против российских энергоресурсов. Ранее Новак заявлял, что добыча нефти в стране по итогам января сохранилась на уровне 9,8-9,9 млн б/с.
# --------------------------------------------------
#
# https://www.interfax.ru/moscow/887117
# Title: Мороз до -28 градусов прогнозируется в московском регионе в ночь на среду, Date: 2023-02-21 11:18:00, Tags: ['Москва', 'Гидрометцентр', 'Роман Вильфанд', 'Подмосковье']
# Москва. 21 февраля. INTERFAX.RU - Температура до минус 28 градусов прогнозируется в московском регионе в ночь на среду, дневные температуры в среду будут на 8-9 градусов ниже нормы, сообщил "Интерфаксу" научный руководитель Гидрометцентра России Роман Вильфанд. "Самый холодный день прогнозируется завтра. Минимальная температура ночью - минус 19 - минус 21, по области до минус 28 градусов. А дневные температуры - минус 13 - минус 11. Очень холодная погода, которая на 8-9 градусов ниже многолетних значений", - сказал Вильфанд. Как отметил научный руководитель Гидрометцентра, в целом в столичном регионе в среду будет спокойная, морозная погода без осадков. Холодная погода также прогнозируется и 23 февраля - ночные температуры составят минус 18 - минус 16, по области - до минус 23 и без осадков. Днем будет минус 10 - минус 9 градусов, по области до минус 12. Такая температура, как уточнил Вильфанд, тоже примерно на 8 градусов ниже нормы.
# --------------------------------------------------
#
# https://www.interfax.ru/russia/887104
# Title: "Ъ" сообщил о предложении кабмина смягчить наказание за налоговые преступления, Date: 2023-02-21 10:46:00, Tags: ['Минюст РФ', 'Минфин РФ', 'СКР']
# Москва. 21 февраля. INTERFAX.RU - Комиссия правительства по законопроектной деятельности накануне, 20 февраля, одобрило поправки в УК РФ, касающиеся смягчения уголовной ответственности за преступления, связанные с уклонением от уплаты налогов, сообщает "Коммерсантъ" со ссылкой на источник в кабмине. По информации издания, разработанный в правительстве законопроект обязывает следователя отказать в возбуждении уголовного дела или прекратить уже возбужденное дело, если бизнесмен полностью оплатил налоговые недоимки и пени. Кроме того, предлагается снизить сроки давности привлечения к уголовной ответственности за уклонение от уплаты налогов с десяти до шести лет. Как ожидается, правительство должно утвердить данный законопроект на ближайшем заседании в среду, после чего он будет внесен в Госдуму, пишет "Ъ". В пояснительной записке к законопроекту говорится, что он разработан во исполнение изданного в апреле 2022 года поручения президента РФ Владимира Путина "в целях снижения негативных последствий для российской экономики в современных условиях". По данным "Коммерсанта", разработка законопроекта затянулась из-за разногласий между Минюстом РФ, который выступал главным исполнителем, и Минфином и Следственным комитетом России (СКР). Последние два ведомства выражали опасения, что из-за сокращения сроков давности по налоговым преступлениям будет невозможно привлечь неплательщика к уголовной ответственности, если сумма причиненного ущерба является значительной. В качестве альтернативы СКР и Минфин предлагали "просто повысить минимальный размер ущерба, за который сейчас предусмотрена максимальная санкция, с 45 млн до 100 млн руб.", пишет газета. Однако этот вариант отвергли, так как сочли, что он противоречит решению поставленной президентом задачи по снижению административного давления на бизнес.
# --------------------------------------------------
#
# https://www.interfax.ru/business/887110
# Title: Engie инициировала арбитраж о выплате штрафов за недопоставку "Газпромом" газа, Date: 2023-02-21 10:32:00, Tags: ['Engie', 'Газпром']
# Москва. 21 февраля. INTERFAX.RU - Engie в начале четвертого квартала 2022 года инициировала арбитражное разбирательство в отношении ООО "Газпром экспорт", добиваясь, в частности, признания неисполнения обязательств по поставке газа по долгосрочным договорам, говорится в отчете французской компании. Также она добивается выплаты штрафов по договору и компенсации убытков, возникших в результате такого неисполнения со стороны "Газпром экспорта". "Эта арбитражная процедура связана со значительной недопоставкой "Газпром экспортом" компании Engie по состоянию на середину июня 2022 г., за чем последовало одностороннее решение "Газпром экспорта" в конце лета 2022 г. о сокращении поставок компании Engie из-за разногласий сторон (...)", - говорится в документе. Как сообщалось, "Газпром" с 1 сентября 2022 года приостановил прокачку газа в адрес Engie в связи с неоплатой июльских поставок в полном объеме. "В соответствии с указом президента РФ от 31.03.2022 г. 172 "О специальном порядке исполнения иностранными покупателями обязательств перед российскими поставщиками природного газа" (оплата газа за рубли - ИФ) запрещается дальнейшая поставка природного газа иностранному покупателю, если в контрактный срок оплаты платеж не был произведен покупателем в полном объеме", - подчеркивал российский концерн. Engie также сообщила, что стоимость ее вложений в газопровод "Северный поток" в настоящее время оценивается в 90 млн евро, что на 474 млн евро меньше, чем на конец 2021 года. Снижение является результатом повреждения газопровода, а также повышенного риска в отношении единственного клиента "Северного потока" - "Газпрома". Снижение справедливой стоимости не влияет на оценку финансовых результатов, поскольку отражено по другим статьям отчета. Снижение, в частности, включает продажу оставшихся 1,8% акций SUEZ (с убытком в 227 млн евро). До 2015 года Engie называлась GDF SUEZ. Engie была основным импортером российского газа во Францию, а также акционером газопроводов "Северный поток" (9%) и "Северный поток 2" (10%). В первом полугодии 2021 года "Газпром" поставил во Францию 6,6 млрд кубометров газа. В ноябре 2022 года стокгольмский арбитраж по аналогичному иску финской Gasum признал издание указа президента РФ о переходе на оплату газа за рубли "обстоятельством форс-мажора по контракту". "Газпром экспорт" комментировал, что это означает правомерность приостановки поставок газа в случае неосуществления покупателем оплаты в рублях. Кроме того, трибунал обязал финскую компанию выплатить "Газпром экспорту" задолженность за поставки газа, а также обязал стороны продолжить переговоры по контракту для урегулирования ситуации с дальнейшими поставками. Gasum прокомментировал, что, согласно решению арбитража, не обязан платить в рублях, как и принимать предложенный порядок оплаты.
# --------------------------------------------------
# РКК "Энергия" исключает версию брака при производстве космических кораблей "Союз" и "Прогресс"
# https://www.interfax.ru/russia/887089
# Title: "Роскосмос" назвал внешнее воздействие причиной разгерметизации "Прогресса МС-21" на МКС, Date: 2023-02-21 08:10:00, Tags: ['Роскосмос', 'МКС', 'Прогресс МС-21']
# РКК "Энергия" исключает версию брака при производстве космических кораблей "Союз" и "Прогресс" Москва. 21 февраля. INTERFAX.RU - По предварительным данным, разгерметизация системы терморегулирования корабля "Прогресс МС-21" на Международной космической станции (МКС), как и ранее у "Союза МС-22", вызвана внешним воздействием, заявили в "Роскосмосе" во вторник. "По предварительным данным Ракетно-космической корпорации "Энергия" имени С.П. Королева (входит госкорпорацию "Роскосмос"), "Прогресс МС-21", как и ранее "Союз МС-22", подвергся внешнему воздействию", - сказали в пресс-службе госкорпорации. Там отметили, что выводы сделаны на основе снимков, которые показывают изменения на внешней поверхности корабля, в том числе на радиаторе приборно-агрегатного отсека и панелях солнечных батарей. "На них обнаружены отверстия, которые не фиксировались ни при изготовлении "Прогресса МС-21" на заводе, ни во время его подготовки к запуску на космодроме Байконур, ни во время полета и стыковки корабля с МКС", - сообщили в "Роскосмосе". Ракетно-космическая корпорация (РКК) "Энергия" исключила версию брака в системе терморегулирования космических кораблей, проанализировав историю замечаний к системе за последние 15 лет. "Замечаний, которые могли бы привести к такой нештатной ситуации, выявлено не было", - говорится в докладе предприятия, выдержки из которого приводит пресс-служба "Роскосмоса". "Резерв надежности системы терморегулирования составляет один год с момента запуска корабля, поэтому система гарантированно надежна в расчетных условиях ее эксплуатации", - следует из доклада РКК "Энергия". Чтобы защитить космические корабли от метеороидов и космического мусора, "Роскосмос" проведет наземные эксперименты по имитации повреждений "Прогресса МС-21". "Это поможет окончательно проверить все версии и выработать меры по парированию подобного рода угроз при разработке и производстве космических кораблей и аппаратов", - отметили в госкорпорации. 11 февраля в "Роскосмосе" сообщили об утечке теплоносителя из системы терморегулирования корабля "Прогресс МС-21", пристыкованного к МКС. По словам исполнительного директора "Роскосмоса" по пилотируемым программам Сергея Крикалева, разгерметизация корабля "Прогресс МС-21" была похожа на ситуацию, произошедшую в декабре с кораблем "Союз МС-22". 13 февраля глава госкорпорации Юрий Борисов сообщил, что причиной разгерметизации "Прогресса МС-21" могли стать метеорит или космический мусор. 14 февраля специалисты NASA провели осмотр предполагаемого места повреждения корабля "Прогресс МС-21" с помощью камер руки-манипулятора и передали данные российским специалистам для дальнейшего анализа. Затопление "Прогресса МС-21" намечалось на 18 февраля, однако, после анализа результатов съемки, сделанной космонавтами с борта МКС после отстыковки корабля от станции, специалисты госкорпорации не обнаружили визуальных повреждений на грузовике. В связи с этим "Роскосмос" отложил затопление "Прогресса" для дальнейшего выяснения причины его разгерметизации. Впоследствии главная оперативная группа управления РКК "Энергия" приняла решение о сведении "Прогресса МС-21" с орбиты 19 февраля. 15 декабря 2022 года в "Роскосмосе" сообщили об отмене выхода в открытый космос с борта МКС российских космонавтов из-за разгерметизации контура наружного радиатора корабля "Союз МС-22". 11 января Борисов сказал, что исследования подтвердили, что корабль был поврежден метеороидом. Диаметр повреждения на поверхности приборного отсека корабля составил до 1 мм, предполагается, что отверстие на скорости пробил элемент космического мусора. Предполагается, что поврежденный "Союз МС-22" спустят на Землю в беспилотном режиме в конце марта.
